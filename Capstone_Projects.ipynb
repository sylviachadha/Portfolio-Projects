# %% [markdown]
# # Capstone Project

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Deliverables - Based on problem statement & dataset

# %% [markdown]
# If Project on ML -
#
# 1. Pre-processed data
# 2. Saved model, if many ML models you can submit all files for all models tried.
# 3. Business Presentation including technical details required
#
# - Problem can be approached & solved in different way. Your innovation can be added on it as a flavour.
# - Requirement is you're on **problem statement**, the **solution in terms of format** & **presentation in form of ppt** or word format.
# - Not like UG or PG presentation but how business people will understand your project what is your achievement.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# All deliverables to be uploaded on LMS before 9th April 2023.

# %% [markdown]
# # List of Projects

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Project Storyboarding template

# %% [markdown]
# - To ensure all Key components are leveraged & included when project submission happens.
# - Each and every problem is independently different from others so Storyline can be given by your mentor - what is requirement, target and achievement.
# - Template will be given by mentor, clear cut picture from start to end, what is your storyline.
# - Previous solutions (something as a reference template can be provided but not that particular problem), how your inference can be plotted on a business way of presenting the problem.
# - Timelines for project. If project related to EDA, ML then can start after 1st mentoring session but if selection related to specialization then need to wait until module started or LMS opened.
# - Mentoring session.

# %% [markdown]
# # Evaluation

# %% [markdown]
# - Each and every problem is independently different from others hence cannot make a standard procedure to evaluate the project.
# - Scope of every problem is different. If giving text problem & telling u do lot of eda sometimes scope is not there.
# - Evaluation & feedback will be more based on insights of data, how u understand and present the data in terms business presentation, if eda project.
# - If ML problem evaluation will be based on accuracy (performance metric), classification report, optimization techniques used (hyperparameter tuning).
# - For all projects, there will be a ppt presentation.

# %% [markdown]
# ![image.png](attachment:image.png)
